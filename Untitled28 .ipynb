# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
df.iloc[1]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %%
"""
loc (Label-based selection):
loc is primarily label-based, meaning it selects data based on the row and column labels.
It uses the actual labels or index names to make selections.
You can use column names and index labels to specify what data you want to retrieve.
Inclusive slicing is used, meaning both the start and stop indices are included when using slices.

Example:
df.loc[2, 'Column_name']  # Selects the element in row with index 2 and 'Column_name'
df.loc[1:3, 'Column1':'Column3']  # Selects rows 1, 2, 3 and columns 'Column1', 'Column2', 'Column3'

iloc (Integer-based selection):
iloc is primarily integer-based, meaning it selects data based on integer positions or numeric indices.
It uses integer row and column positions to make selections.
You can use integer indices to specify what data you want to retrieve.
Exclusive slicing is used, meaning the stop index is excluded when using slices.
Example:
df.iloc[2, 1]  # Selects the element in the third row (index 2) and second column (index 1)
df.iloc[1:4, 0:3]  # Selects rows 1, 2, 3 and columns 0, 1, 2
"""
# Out:
# "\nloc (Label-based selection):\nloc is primarily label-based, meaning it selects data based on the row and column labels.\nIt uses the actual labels or index names to make selections.\nYou can use column names and index labels to specify what data you want to retrieve.\nInclusive slicing is used, meaning both the start and stop indices are included when using slices.\n\nExample:\ndf.loc[2, 'Column_name']  # Selects the element in row with index 2 and 'Column_name'\ndf.loc[1:3, 'Column1':'Column3']  # Selects rows 1, 2, 3 and columns 'Column1', 'Column2', 'Column3'\n\niloc (Integer-based selection):\niloc is primarily integer-based, meaning it selects data based on integer positions or numeric indices.\nIt uses integer row and column positions to make selections.\nYou can use integer indices to specify what data you want to retrieve.\nExclusive slicing is used, meaning the stop index is excluded when using slices.\nExample:\ndf.iloc[2, 1]  # Selects the element in the third row (index 2) and second column (index 1)\ndf.iloc[1:4, 0:3]  # Selects rows 1, 2, 3 and columns 0, 1, 2\n"

# %%
new_df=df.reindex([3,0,1,2])
new_df.loc[2]
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object

# %%
new_df.iloc[2]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %%
# The key difference is that loc uses labels (index names) for selection, whereas iloc uses integer positions for selection.
# Depending on the DataFrame's index and the reindexing you performed, these two methods can give different results.

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.134877  0.485585  0.130065  0.138425  0.108354  0.205102
# 2  0.988503  0.987878  0.242056  0.984529  0.792634  0.387821
# 3  0.113612  0.523238  0.690031  0.208116  0.929195  0.193335
# 4  0.500068  0.292145  0.112455  0.518384  0.338510  0.425568
# 5  0.862274  0.225885  0.839136  0.111352  0.929806  0.107588
# 6  0.416330  0.376393  0.696804  0.221645  0.237629  0.288263

# %%
df1.mean()
# Out:
# column_1    0.502611
# column_2    0.481854
# column_3    0.451758
# column_4    0.363742
# column_5    0.556021
# column_6    0.267946
# dtype: float64

# %%
df1['column_2'].std()
# Out:
# 0.2721832220096908

# %%
df1.loc[2, 'column_2'] ="Aayush"

# %%
df1['column_2'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d021c1d6b2aa> in <cell line: 1>()
# ----> 1 df1['column_2'].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11351                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352             )
# > 11353         return self._reduce(
#   11354             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4814                 )
#    4815             with np.errstate(all="ignore"):
# -> 4816                 return op(delegate, skipna=skipna, **kwds)
#    4817
#    4818     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     416             mask = isna(values)
#     417
# --> 418         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     419
#     420         if datetimelike:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     704
#     705     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     707
#     708     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# float + string not possible hence error occured

# %%
# In Pandas, window functions (also known as windowing or rolling functions) are operations that perform calculations on a specific subset of data points within a defined window or "rolling" range of data points. These functions are commonly used for time series data and data with ordered indices, but they can also be applied to other types of data.
# Window functions in Pandas are typically used in conjunction with the rolling() method, which creates a rolling view of the data.
# It's Types are :- Aggregate,Transformation,Expanding,etc.

# %%
import datetime
current_date = datetime.datetime.now()
current_month = current_date.strftime('%B')
current_year = current_date.year
print(current_date)
print(f"Current Month: {current_month}")
print(f"Current Year: {current_year}")
# Out:
# 2023-09-18 11:53:08.898260
# Current Month: September
# Current Year: 2023

# %%
date1_str = input("Enter the first date (YYYY-MM-DD): ")
date2_str = input("Enter the second date (YYYY-MM-DD): ")
date1 = pd.to_datetime(date1_str)
date2 = pd.to_datetime(date2_str)
time_difference = date2 - date1
days = time_difference.days
hours, remainder = divmod(time_difference.seconds, 3600)
minutes = remainder
print(f"Difference: {days} days, {hours} hours, {minutes} minutes")
# Out:
# Enter the first date (YYYY-MM-DD): 2022-11-06
# Enter the second date (YYYY-MM-DD): 2020-10-04
# Difference: -763 days, 0 hours, 0 minutes

# %%
df2=pd.read_csv('https://code.datasciencedojo.com/datasciencedojo/datasets/raw/master/Hepatitis%20C%20Virus%20(HCV)%20Classification%20Dataset/Hepatitis%20C%20Virus%20(HCV)%20Classification%20Dataset.csv')

# %%
df2
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  \
# 0          5       5               5    655330  634536   288194        5
# 1         57     123              44     40620  538635   637056   336804
# 2          5       5               5    571148  661346        5   735945
# 3         48      77              33   1041941  449939   585688   744463
# 4         94      90              30    660410  738756  3731527   338946
# ...      ...     ...             ...       ...     ...      ...      ...
# 1380      63      44              45    387795   55938        5        5
# 1381      97      64              41    481378  152961   393339    73574
# 1382      87      39              24    612664  572756   806109   343719
# 1383      48      81              43    139872   76161   515730     2460
# 1384      64      71              34   1190577  628730        5        5
#
#       RNA EF  Baseline histological Grading  Baselinehistological staging
# 0          5                             13                             2
# 1      31085                              4                             2
# 2     558829                              4                             4
# 3     582301                             10                             3
# 4     242861                             11                             1
# ...      ...                            ...                           ...
# 1380       5                             15                             4
# 1381  236273                             10                             2
# 1382  160457                              6                             2
# 1383  696074                             15                             3
# 1384       5                             13                             3
#
# [1385 rows x 29 columns]

# %%
pd.Categorical(df2)
# Out:
# ['Age ', 'Gender', 'BMI', 'Fever', 'Nausea/Vomting', ..., 'RNA 12', 'RNA EOT', 'RNA EF', 'Baseline histological Grading', 'Baselinehistological staging']
# Length: 29
# Categories (29, object): ['ALT 1', 'ALT 12', 'ALT 24', 'ALT 36', ..., 'RNA Base', 'RNA EF',
#                           'RNA EOT', 'WBC']

# %%
df3=pd.read_csv('https://gist.githubusercontent.com/fishtai0/5975c7e38c8566b9b3144e45a99b65cf/raw/941a7ecbab78d6032393ba8eed6579a563f126d6/company-sales.csv')

# %%
df3
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
import seaborn as sns

# %%
sns.barplot(data=df3, x="month_number", y="total_profit")
# Out:
# <Axes: xlabel='month_number', ylabel='total_profit'>

# %%
from statistics import mean, median, mode

# %%
data3=pd.read_csv('/content/sample_data/student-scores.csv')
df4=pd.DataFrame(data3)
df4
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0       male          False             3                       False
# 1     female          False             2                       False
# 2     female          False             9                        True
# 3     female          False             5                       False
# 4       male          False             5                       False
# ...      ...            ...           ...                         ...
# 1995    male          False             2                       False
# 1996    male          False             2                       False
# 1997  female          False             5                       False
# 1998  female           True            10                        True
# 1999  female          False             5                       False
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10                Unknown          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score
# 0                80               87
# 1                88               90
# 2                77               94
# 3                63               86
# 4                74               76
# ...             ...              ...
# 1995             84               82
# 1996             67               73
# 1997             94               78
# 1998             88               75
# 1999             93              100
#
# [2000 rows x 17 columns]

# %%
df4['total_score'] = df4['history_score']+df4['physics_score']+df4['chemistry_score']+df4['biology_score']+df4['english_score']+df4['geography_score']
# Write the updated DataFrame back to a CSV file
df4.to_csv('https://gist.githubusercontent.com/fishtai0/5975c7e38c8566b9b3144e45a99b65cf/raw/941a7ecbab78d6032393ba8eed6579a563f126d6/company-sales.csv', index=False)

# %%
df4
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0       male          False             3                       False
# 1     female          False             2                       False
# 2     female          False             9                        True
# 3     female          False             5                       False
# 4       male          False             5                       False
# ...      ...            ...           ...                         ...
# 1995    male          False             2                       False
# 1996    male          False             2                       False
# 1997  female          False             5                       False
# 1998  female           True            10                        True
# 1999  female          False             5                       False
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10                Unknown          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score  total_score
# 0                80               87          501
# 1                88               90          550
# 2                77               94          524
# 3                63               86          480
# 4                74               76          437
# ...             ...              ...          ...
# 1995             84               82          475
# 1996             67               73          445
# 1997             94               78          481
# 1998             88               75          515
# 1999             93              100          535
#
# [2000 rows x 18 columns]

# %%
mean_score=mean(df4['total_score'])
median_score=median(df4['total_score'])
mode_score=mode(df4['total_score'])

# %%
print(f" Mean={mean_score}\n Median={median_score} \n Mode={mode_score}")
# Out:
#  Mean=483.4105
#  Median=482.0
#  Mode=481
